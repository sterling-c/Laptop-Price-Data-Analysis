# %%
import pandas as pd
import os

# %%
pwd
# Out:
# 'C:\\Users\\sclark18\\Documents\\Data Projects\\Project 1\\Source Code'

# %%
laptop_data = pd.read_csv("C:/Users/sclark18/Documents/Data Projects/Project 1/Data/laptops.csv", encoding='latin-1')
laptop_data.head()
# Out:
#    Unnamed: 0 Company      Product   TypeName  Inches  \
# 0           1   Apple  MacBook Pro  Ultrabook    13.3
# 1           2   Apple  Macbook Air  Ultrabook    13.3
# 2           3      HP       250 G6   Notebook    15.6
# 3           4   Apple  MacBook Pro  Ultrabook    15.4
# 4           5   Apple  MacBook Pro  Ultrabook    13.3
#
#                      ScreenResolution                         Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz   8GB
# 1                            1440x900        Intel Core i5 1.8GHz   8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz   8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz  16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz   8GB
#
#                 Memory                           Gpu  OpSys  Weight  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS  1.37kg
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS  1.34kg
# 2            256GB SSD         Intel HD Graphics 620  No OS  1.86kg
# 3            512GB SSD            AMD Radeon Pro 455  macOS  1.83kg
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS  1.37kg
#
#    Price_euros
# 0      1339.69
# 1       898.94
# 2       575.00
# 3      2537.45
# 4      1803.60

# %%
list(laptop_data.columns)
# Out:
# ['Unnamed: 0',
#  'Company',
#  'Product',
#  'TypeName',
#  'Inches',
#  'ScreenResolution',
#  'Cpu',
#  'Ram',
#  'Memory',
#  'Gpu',
#  'OpSys',
#  'Weight',
#  'Price_euros']

# %%
laptop_data = laptop_data.drop(columns="Unnamed: 0")
laptop_data.tail()
# Out:
#      Company                              Product            TypeName  Inches  \
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible    14.0
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible    13.3
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook    14.0
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook    15.6
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook    15.6
#
#                                 ScreenResolution  \
# 1298   IPS Panel Full HD / Touchscreen 1920x1080
# 1299  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300                                    1366x768
# 1301                                    1366x768
# 1302                                    1366x768
#
#                                        Cpu   Ram              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz   4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz  16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz   2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz   6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz   4GB           500GB HDD
#
#                         Gpu       OpSys  Weight  Price_euros
# 1298  Intel HD Graphics 520  Windows 10   1.8kg        638.0
# 1299  Intel HD Graphics 520  Windows 10   1.3kg       1499.0
# 1300      Intel HD Graphics  Windows 10   1.5kg        229.0
# 1301     AMD Radeon R5 M330  Windows 10  2.19kg        764.0
# 1302      Intel HD Graphics  Windows 10   2.2kg        369.0

# %%
laptop_data = laptop_data.rename(columns={"Ram": "RAM(in GB)", "TypeName": "Product Type", "Inches": "Length(in inches)", "Weight": "Weight(in kg)", "Price_euros": "Price(in euros)"})
laptop_data.tail()
# Out:
#      Company                              Product        Product Type  \
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Length(in inches)                            ScreenResolution  \
# 1298               14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299               13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300               14.0                                    1366x768
# 1301               15.6                                    1366x768
# 1302               15.6                                    1366x768
#
#                                        Cpu RAM(in GB)              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz        4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz       16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz        2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz        6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz        4GB           500GB HDD
#
#                         Gpu       OpSys Weight(in kg)  Price(in euros)
# 1298  Intel HD Graphics 520  Windows 10         1.8kg            638.0
# 1299  Intel HD Graphics 520  Windows 10         1.3kg           1499.0
# 1300      Intel HD Graphics  Windows 10         1.5kg            229.0
# 1301     AMD Radeon R5 M330  Windows 10        2.19kg            764.0
# 1302      Intel HD Graphics  Windows 10         2.2kg            369.0

# %%
laptop_data = laptop_data.rename(columns={"Ram": "RAM (in GB)", "Inches": "Length (in inches)", "Weight": "Weight (in kg)", "Price_euros": "Price (in euros)"})
laptop_data.tail()
# Out:
#      Company                              Product        Product Type  \
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Length(in inches)                            ScreenResolution  \
# 1298               14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299               13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300               14.0                                    1366x768
# 1301               15.6                                    1366x768
# 1302               15.6                                    1366x768
#
#                                        Cpu RAM(in GB)              Memory  \
# 1298            Intel Core i7 6500U 2.5GHz        4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz       16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz        2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz        6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz        4GB           500GB HDD
#
#                         Gpu       OpSys Weight(in kg)  Price(in euros)
# 1298  Intel HD Graphics 520  Windows 10         1.8kg            638.0
# 1299  Intel HD Graphics 520  Windows 10         1.3kg           1499.0
# 1300      Intel HD Graphics  Windows 10         1.5kg            229.0
# 1301     AMD Radeon R5 M330  Windows 10        2.19kg            764.0
# 1302      Intel HD Graphics  Windows 10         2.2kg            369.0

# %%
laptop_data = laptop_data.rename(columns={"Memory": "Storage Memory"})

# %%
laptop_data.tail()
# Out:
#      Company                              Product        Product Type  \
# 1298  Lenovo                       Yoga 500-14ISK  2 in 1 Convertible
# 1299  Lenovo                       Yoga 900-13ISK  2 in 1 Convertible
# 1300  Lenovo                   IdeaPad 100S-14IBR            Notebook
# 1301      HP  15-AC110nv (i7-6500U/6GB/1TB/Radeon            Notebook
# 1302    Asus  X553SA-XX031T (N3050/4GB/500GB/W10)            Notebook
#
#       Length(in inches)                            ScreenResolution  \
# 1298               14.0   IPS Panel Full HD / Touchscreen 1920x1080
# 1299               13.3  IPS Panel Quad HD+ / Touchscreen 3200x1800
# 1300               14.0                                    1366x768
# 1301               15.6                                    1366x768
# 1302               15.6                                    1366x768
#
#                                        Cpu RAM(in GB)      Storage Memory  \
# 1298            Intel Core i7 6500U 2.5GHz        4GB           128GB SSD
# 1299            Intel Core i7 6500U 2.5GHz       16GB           512GB SSD
# 1300  Intel Celeron Dual Core N3050 1.6GHz        2GB  64GB Flash Storage
# 1301            Intel Core i7 6500U 2.5GHz        6GB             1TB HDD
# 1302  Intel Celeron Dual Core N3050 1.6GHz        4GB           500GB HDD
#
#                         Gpu       OpSys Weight(in kg)  Price(in euros)
# 1298  Intel HD Graphics 520  Windows 10         1.8kg            638.0
# 1299  Intel HD Graphics 520  Windows 10         1.3kg           1499.0
# 1300      Intel HD Graphics  Windows 10         1.5kg            229.0
# 1301     AMD Radeon R5 M330  Windows 10        2.19kg            764.0
# 1302      Intel HD Graphics  Windows 10         2.2kg            369.0

# %%
laptop_data['Weight(in kg)'] = laptop_data['Weight(in kg)'].str.strip('kg')

# %%
laptop_data['Price(in euros)'] = laptop_data['Price(in euros)'].round(2)
laptop_data.head()
# Out:
#   Company      Product Product Type  Length(in inches)  \
# 0   Apple  MacBook Pro    Ultrabook               13.3
# 1   Apple  Macbook Air    Ultrabook               13.3
# 2      HP       250 G6     Notebook               15.6
# 3   Apple  MacBook Pro    Ultrabook               15.4
# 4   Apple  MacBook Pro    Ultrabook               13.3
#
#                      ScreenResolution                         Cpu RAM(in GB)  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz        8GB
# 1                            1440x900        Intel Core i5 1.8GHz        8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz        8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz       16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz        8GB
#
#         Storage Memory                           Gpu  OpSys Weight(in kg)  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS          1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS          1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS          1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS          1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS          1.37
#
#    Price(in euros)
# 0          1339.69
# 1           898.94
# 2           575.00
# 3          2537.45
# 4          1803.60

# %%
laptop_data.head()
# Out:
#   Company      Product Product Type  Length(in inches)  \
# 0   Apple  MacBook Pro    Ultrabook               13.3
# 1   Apple  Macbook Air    Ultrabook               13.3
# 2      HP       250 G6     Notebook               15.6
# 3   Apple  MacBook Pro    Ultrabook               15.4
# 4   Apple  MacBook Pro    Ultrabook               13.3
#
#                      ScreenResolution                         Cpu RAM(in GB)  \
# 0  IPS Panel Retina Display 2560x1600        Intel Core i5 2.3GHz        8GB
# 1                            1440x900        Intel Core i5 1.8GHz        8GB
# 2                   Full HD 1920x1080  Intel Core i5 7200U 2.5GHz        8GB
# 3  IPS Panel Retina Display 2880x1800        Intel Core i7 2.7GHz       16GB
# 4  IPS Panel Retina Display 2560x1600        Intel Core i5 3.1GHz        8GB
#
#         Storage Memory                           Gpu  OpSys Weight(in kg)  \
# 0            128GB SSD  Intel Iris Plus Graphics 640  macOS          1.37
# 1  128GB Flash Storage        Intel HD Graphics 6000  macOS          1.34
# 2            256GB SSD         Intel HD Graphics 620  No OS          1.86
# 3            512GB SSD            AMD Radeon Pro 455  macOS          1.83
# 4            256GB SSD  Intel Iris Plus Graphics 650  macOS          1.37
#
#    Price(in euros)
# 0          1339.69
# 1           898.94
# 2           575.00
# 3          2537.45
# 4          1803.60

# %%
# This was an attempt to reformat some of the data within panda dataframe for clarification and consistency.
# We will write a new CSV file using the current format of the dataframe, then move on with the actual analysis.

# %%
laptop_data.to_csv("C:/Users/sclark18/Documents/Data Projects/Project 1/Data/laptops_clean.csv")

# %%
# Now we will compare each company's average price.

# %%
company_list = laptop_data['Company'].unique().tolist()

# %%
print(company_list)
# Out:
# ['Apple', 'HP', 'Acer', 'Asus', 'Dell', 'Lenovo', 'Chuwi', 'MSI', 'Microsoft', 'Toshiba', 'Huawei', 'Xiaomi', 'Vero', 'Razer', 'Mediacom', 'Samsung', 'Google', 'Fujitsu', 'LG']

# %%
average_price = []

# %%
avg_dict = {}
for company in company_list:
    product_count = 0
    price_sum = 0
    for index, row in laptop_data.iterrows():
        if(row['Company'] == company):
            product_count = product_count + 1
            price_sum = price_sum + row['Price(in euros)']
    avg_price = format(price_sum/product_count, '.2f')
    avg_dict[company] = avg_price

# %%
print(avg_dict)
# Out:
# {'Apple': '1564.20', 'HP': '1067.77', 'Acer': '626.78', 'Asus': '1104.17', 'Dell': '1186.07', 'Lenovo': '1086.38', 'Chuwi': '314.30', 'MSI': '1728.91', 'Microsoft': '1612.31', 'Toshiba': '1267.81', 'Huawei': '1424.00', 'Xiaomi': '1133.46', 'Vero': '217.43', 'Razer': '3346.14', 'Mediacom': '295.00', 'Samsung': '1413.44', 'Google': '1677.67', 'Fujitsu': '729.00', 'LG': '2099.00'}

# %%
company_price_compare = pd.DataFrame.from_dict(avg_dict, orient='index')

# %%
company_price_compare
# Out:
#                  0
# Apple      1564.20
# HP         1067.77
# Acer        626.78
# Asus       1104.17
# Dell       1186.07
# Lenovo     1086.38
# Chuwi       314.30
# MSI        1728.91
# Microsoft  1612.31
# Toshiba    1267.81
# Huawei     1424.00
# Xiaomi     1133.46
# Vero        217.43
# Razer      3346.14
# Mediacom    295.00
# Samsung    1413.44
# Google     1677.67
# Fujitsu     729.00
# LG         2099.00

# %%
list(company_price_compare.columns)
# Out:
# ['Price (in euros)']

# %%
company_price_compare = company_price_compare.rename(columns={0: "Price (in euros)"})

# %%
company_price_compare
# Out:
#           Price (in euros)
# Apple              1564.20
# HP                 1067.77
# Acer                626.78
# Asus               1104.17
# Dell               1186.07
# Lenovo             1086.38
# Chuwi               314.30
# MSI                1728.91
# Microsoft          1612.31
# Toshiba            1267.81
# Huawei             1424.00
# Xiaomi             1133.46
# Vero                217.43
# Razer              3346.14
# Mediacom            295.00
# Samsung            1413.44
# Google             1677.67
# Fujitsu             729.00
# LG                 2099.00

# %%
import matplotlib.pyplot as plt
df=company_price_compare.astype(float)
ax = df[['Price (in euros)']].plot.bar()
ax.set_xlabel("Companies", fontsize=12)
ax.set_ylabel("Price(in euros)", fontsize=12)
plt.show()
